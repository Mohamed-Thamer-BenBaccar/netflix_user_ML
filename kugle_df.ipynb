# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = ""

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "rhythmghai/netflix-user-watching-behavior-dataset",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Install dependencies as needed:
#       2 # pip install kagglehub[pandas-datasets]
# ----> 3 import kagglehub
#       4 from kagglehub import KaggleDatasetAdapter
#       6 # Set the path to the file you'd like to load
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
pip install kagglehub[pandas-datasets]
# Out:
# ...
#   Obtaining dependency information for kagglehub[pandas-datasets] from https://files.pythonhosted.org/packages/18/78/08cec00ea05fd2469f9395da0306bb368c4ed275693be8d31473eafaf90c/kagglehub-1.0.0-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/40.1 kB ? eta -:--:--
#      ------------------- ------------------ 20.5/40.1 kB 217.9 kB/s eta 0:00:01
#      ----------------------------- -------- 30.7/40.1 kB 262.6 kB/s eta 0:00:01
#      -------------------------------------- 40.1/40.1 kB 238.6 kB/s eta 0:00:00
# ...
#   Obtaining dependency information for kagglesdk<1.0,>=0.1.14 from https://files.pythonhosted.org/packages/69/6b/db30f17ad132391ac37a751fa45b32fd954a7ffa484fa3550eee9678334d/kagglesdk-0.1.16-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pyyaml from https://files.pythonhosted.org/packages/86/bf/899e81e4cce32febab4fb42bb97dcdf66bc135272882d1987881a4b519e9/pyyaml-6.0.3-cp312-cp312-win_amd64.whl.metadata
# ...

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "rhythmghai/netflix-user-watching-behavior-dataset",
    "netflix_user_watching_behavior.csv"  # specify the filename
)

print(df.head())
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File d:\ESGITECH\2eme_semestre\Machine_learning_avec_Python_Analyse_et_Programmation_\Mini-Project_Supervised_Learning\ml-env\Lib\site-packages\kagglehub\exceptions.py:67, in handle_call(fn, resource_handle)
#      66 try:
# ---> 67     return fn()
#      68 except requests.HTTPError as e:
#
# File d:\ESGITECH\2eme_semestre\Machine_learning_avec_Python_Analyse_et_Programmation_\Mini-Project_Supervised_Learning\ml-env\Lib\site-packages\kagglehub\http_resolver.py:144, in DatasetHttpResolver._resolve.<locals>.<lambda>()
#     143 os.makedirs(os.path.dirname(out_path), exist_ok=True)
# --> 144 response = handle_call(lambda: api_client.datasets.dataset_api_client.download_dataset(r), h)
#     145 download_file(response, out_path, h, extract_auto_compressed_file=True)
#
# ...

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = ""

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "rhythmghai/netflix-user-watching-behavior-dataset",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# C:\Users\INFOKOM\AppData\Local\Temp\ipykernel_24112\3599319407.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 10
#       7 file_path = ""
#       9 # Load the latest version
# ---> 10 df = kagglehub.load_dataset(
#      11   KaggleDatasetAdapter.PANDAS,
#      12   "rhythmghai/netflix-user-watching-behavior-dataset",
#      13   file_path,
#      14   # Provide any additional arguments like
#      15   # sql_query or pandas_kwargs. See the
#      16   # documenation for more information:
#      17   # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
#      18 )
#      20 print("First 5 records:", df.head())
#
# ...
